# %%
# !pip install jsonpath_ng
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jsonpath_ng in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: ply in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (3.11)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (1.16.0)

# %%
import os
import json
import numpy as np 
import pandas as pd 
import sqlite3
import functools as ft
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from jsonpath_ng import parse
from enum import Enum
# %matplotlib inline

# %%
with open("nett.json", "r") as file:
    data = json.load(file)
    for item in data:
        item["Title"] = str(item["Title"])
        item["IMDbScore"] = str(item["IMDbScore"])
        item["IMDbVotes"] = str(item["IMDbVotes"])
        item["AwardsReceived"] = str(item["AwardsReceived"])
        item["NetflixReleaseDate"] = str(item["NetflixReleaseDate"])
        item["ProductionHouse"] = str(item["ProductionHouse"])

        
data[:5]
# Out:
# [{'Title': 'Lets Fight Ghost',
#   'Genre': 'Crime, Drama, Fantasy, Horror, Romance',
#   'Languages': 'Swedish, Spanish',
#   'SeriesOrMovie': 'Series',
#   'HiddenGemScore': 4.3,
#   'Runtime': '< 30 minutes',
#   'Director': 'Tomas Alfredson',
#   'Writer': 'John Ajvide Lindqvist',
#   'Actors': 'Lina Leandersson, Kåre Hedebrant, Per Ragnar, Henrik Dahl',
#   'ViewRating': 'R',
#   'IMDbScore': '7.9',
#   'RottenTomatoesScore': 98,
#   'MetacriticScore': 82,
#   'AwardsReceived': '74',
#   'AwardsNominatedFor': 57,
#   'Boxoffice': 2122065,
#   'ReleaseDate': '##########',
#   'NetflixReleaseDate': '2021-03-04',
#   'ProductionHouse': 'Canal+, Sandrew Metronome',
#   'NetflixLink': 'https://www.netflix.com/watch/81415947',
#   'IMDbLink': 'https://www.imdb.com/title/tt1139797',
#   'IMDbVotes': '205926',
#   'Image': 'https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABcmgLCxN8dNahdY2kgd1hhcL2a6XrE92x24Bx5h6JFUvH5zMrv6lFWl_aWMt33b6DHvkgsUeDx_8Q1rmopwT3fuF8Rq3S1hrkvFf3uzVv2sb3zrtU-LM1Zy1FfrAKD3nKNyA_RQWrmw.jpg?r=cd0',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOWM4NTY2NTMtZDZlZS00NTgyLWEzZDMtODE3ZGI1MzI3ZmU5XkEyXkFqcGdeQXVyNzI1NzMxNzM@._V1_SX300.jpg',
#   'TMDbTrailer': 'https://www.youtube.com/watch?v=LqB6XJix-dM',
#   'TrailerSite': 'YouTube'},
#  {'Title': 'HOW TO BUILD A GIRL',
#   'Genre': 'Comedy',
#   'Languages': 'English',
#   'SeriesOrMovie': 'Movie',
#   'HiddenGemScore': 7,
#   'Runtime': '1-2 hour',
#   'Director': 'Coky Giedroyc',
#   'Writer': 'Caitlin Moran',
#   'Actors': 'Cleo, Paddy Considine, Beanie Feldstein, Dónal Finn',
#   'ViewRating': 'R',
#   'IMDbScore': '5.8',
#   'RottenTomatoesScore': 79,
#   'MetacriticScore': 69,
#   'AwardsReceived': '1',
#   'AwardsNominatedFor': 'none',
#   'Boxoffice': 70632,
#   'ReleaseDate': '08 מאי 2020',
#   'NetflixReleaseDate': '2021-03-04',
#   'ProductionHouse': 'Film 4, Monumental Pictures, Lionsgate',
#   'NetflixLink': 'https://www.netflix.com/watch/81041267',
#   'IMDbLink': 'https://www.imdb.com/title/tt4193072',
#   'IMDbVotes': '2838',
#   'Image': 'https://occ-0-1081-999.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABe_fxMSBM1E-sSoszr12SmkI-498sqBWrEyhkchdn4UklQVjdoPS_Hj-NhvgbePvwlDSzMTcrIE0kgiy-zTEU_EaGg.jpg?r=35a',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZGUyN2ZlMjYtZTk2Yy00MWZiLWIyMDktMzFlMmEzOWVlMGNiXkEyXkFqcGdeQXVyMTE1MzI2NzIz._V1_SX300.jpg',
#   'TMDbTrailer': 'https://www.youtube.com/watch?v=eIbcxPy4okQ',
#   'TrailerSite': 'YouTube'},
#  {'Title': 'The Con-Heartist',
#   'Genre': 'Comedy, Romance',
#   'Languages': 'Thai',
#   'SeriesOrMovie': 'Movie',
#   'HiddenGemScore': 8.6,
#   'Runtime': '> 2 hrs',
#   'Director': 'Mez Tharatorn',
#   'Writer': 'Pattaranad Bhiboonsawade, Mez Tharatorn, Thodsapon Thiptinnakorn',
#   'Actors': 'Kathaleeya McIntosh, Nadech Kugimiya, Pimchanok Leuwisetpaiboon, Thiti Mahayotaruk',
#   'ViewRating': 'no rate',
#   'IMDbScore': '7.4',
#   'RottenTomatoesScore': 'none',
#   'MetacriticScore': 'none',
#   'AwardsReceived': 'None',
#   'AwardsNominatedFor': None,
#   'Boxoffice': None,
#   'ReleaseDate': '##########',
#   'NetflixReleaseDate': '2021-03-03',
#   'ProductionHouse': 'None',
#   'NetflixLink': 'https://www.netflix.com/watch/81306155',
#   'IMDbLink': 'https://www.imdb.com/title/tt13393728',
#   'IMDbVotes': '131',
#   'Image': 'https://occ-0-2188-64.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABSj6td_whxb4en62Ax5EKSKMl2lTzEK5CcBhwBdjRgF6SOJb4RtVoLhPAUWEskuOxPiaafxU1qauZDTJguwNQ9GstA.jpg?r=e76',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BODAzOGZmNjUtMTIyMC00NGU1LTg5MTMtZWY4MDdiZjI0NGEwXkEyXkFqcGdeQXVyNzEyMTA5MTU@._V1_SX300.jpg',
#   'TMDbTrailer': 'https://www.youtube.com/watch?v=md3CmFLGK6Y',
#   'TrailerSite': 'YouTube'},
#  {'Title': 'Gleboka woda',
#   'Genre': 'Drama',
#   'Languages': 'Polish',
#   'SeriesOrMovie': 'Series',
#   'HiddenGemScore': 8.7,
#   'Runtime': '< 30 minutes',
#   'Director': None,
#   'Writer': None,
#   'Actors': 'Katarzyna Maciag, Piotr Nowak, Marcin Dorocinski, Julia Kijowska',
#   'ViewRating': 'no rate',
#   'IMDbScore': '7.5',
#   'RottenTomatoesScore': 'none',
#   'MetacriticScore': 'none',
#   'AwardsReceived': '2',
#   'AwardsNominatedFor': 4,
#   'Boxoffice': 'none',
#   'ReleaseDate': '14 יוני 2011',
#   'NetflixReleaseDate': '2021-03-03',
#   'ProductionHouse': 'none',
#   'NetflixLink': 'https://www.netflix.com/watch/81307527',
#   'IMDbLink': 'https://www.imdb.com/title/tt2300049',
#   'IMDbVotes': '47',
#   'Image': 'https://occ-0-2508-2706.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABSxWH_aWvJrqXWANpOp86kFpU3kdpqx9RsdYZZGHfpIalSig2QHKaZXm8vhKWr89-OLh5XqzIHj_5UzwNriADy19NQ.jpg?r=561',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc0NzZiYTYtMTQyNy00Mjg0LTk1NzMtMTljMjI4ZmM4ZjFmXkEyXkFqcGdeQXVyMTc4MzI2NQ@@._V1_SX300.jpg',
#   'TMDbTrailer': 'https://www.youtube.com/watch?v=5kyF2vy63r0',
#   'TrailerSite': 'YouTube'},
#  {'Title': 'Only a Mother',
#   'Genre': 'Drama',
#   'Languages': 'Swedish',
#   'SeriesOrMovie': 'Movie',
#   'HiddenGemScore': 8.3,
#   'Runtime': '1-2 hour',
#   'Director': 'Alf Sjöberg',
#   'Writer': 'Ivar Lo-Johansson',
#   'Actors': 'Hugo Björne, Eva Dahlbeck, Ulf Palme, Ragnar Falck',
#   'ViewRating': 'no rate',
#   'IMDbScore': '6.7',
#   'RottenTomatoesScore': 'none',
#   'MetacriticScore': 'none',
#   'AwardsReceived': '2',
#   'AwardsNominatedFor': 1,
#   'Boxoffice': 'none',
#   'ReleaseDate': '##########',
#   'NetflixReleaseDate': '2021-03-03',
#   'ProductionHouse': 'none',
#   'NetflixLink': 'https://www.netflix.com/watch/81382068',
#   'IMDbLink': 'https://www.imdb.com/title/tt0041155',
#   'IMDbVotes': '88',
#   'Image': 'https://occ-0-2851-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABdpOFktQ4Z3klQEU2XQc9NWompf70CHEGLPIeBdCGGLDhvy1Mqly5552DUYR5-5M77STCj8rPvCbXltOcTj53olEzA.jpg?r=c84',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjVmMzA5OWYtNTFlMy00ZDBlLTg4NDUtM2NjYjFhMGYwZjBkXkEyXkFqcGdeQXVyNzQxNDExNTU@._V1_SX300.jpg',
#   'TMDbTrailer': 'https://www.youtube.com/watch?v=H0itWKFwMpQ',
#   'TrailerSite': 'YouTube'}]

# %%
class Interface(ABC):

    @abstractmethod
    def get_data_by_field(self, field_name):
        """Fetch the data by given feild name """

    @abstractmethod
    def get_data_by_id(self, id):
        """Fetch the data by given ID  """

    @abstractmethod
    def get(self):
        """Fetch all data """

# %%
class TransformMask(Enum):
    CLEAN_STRING = ".strip().lower()" 
    CAPITAL_LETTER = ".strip().lower().title()"

# %%
keysList = ['Title', 'IMDbScore', 'IMDbVotes', 'AwardsReceived', 'NetflixReleaseDate','ProductionHouse'] 

class Database:
    def __init__(self):
        self.db = {}

    def add_source(self):
        self.db["source"] = []
        for i in range(1, len(keysList) + 1):
            self.db["source"].append({
                "id": i,
                "source_field_name": keysList[i - 1],
                "source_field_mapping": keysList[i - 1],
                "source_field_type": "str",  
                "is_required": True,
            })

    def add_destination(self):
        self.db["destination"] = []
        for i in range(1, len(keysList) + 1):
            self.db["destination"].append({
                "id": i,
                "destination_field_name": keysList[i - 1],
                "destination_field_mapping": keysList[i - 1],
                "destination_field_type": "str",
                "default_value": "n/a",
            })

    def add_transform(self):
        self.db["transform"] = [
            {
                "id": 1,
                "transform_mask": 'CAPITAL_LETTER'
            },
            {
                "id": 2,
                "transform_mask": 'CLEAN_STRING'
            }
        ]

    def add_mapping(self):
        self.db["mapping"] = []
        for i in range(1, len(keysList) + 1):
            self.db["mapping"].append(
                {
                    "id": i,
                    "mapping_source": i,
                    "mapping_destination": i,
                    "mapping_transform": 1
                }
            )

    def data_source_target_mapping(self):
        self.add_source()
        self.add_destination()
        self.add_transform()
        self.add_mapping()

    @property
    def get_data_source_target_mapping(self):
        self.data_source_target_mapping()
        return self.db

# %%
class Source(Interface, Database):
    def __init__(self):
        Database.__init__(self)
    
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("source")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id") == self.id:
                return x
        return None

# %%
class Target(Interface, Database):

    def __init__(self):
        Database.__init__(self)
    
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None


    @property
    def get(self):
        return self.get_data_source_target_mapping.get("destination")
    

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %%
class Transform(Interface, Database):

    def __init__(self):
        Database.__init__(self)
    
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("transform", [])

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %%
class Mappings(Interface, Database):

    def __init__(self):
        Database.__init__(self)
    
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None
    @property
    def get(self):
        return self.get_data_source_target_mapping.get("mapping")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

    def get_data_by_field(self, field_name):
        return None

# %%
class JsonQuery:
    def __init__(self, json_path, json_data):
        self.json_path = json_path
        self.json_data = json_data

    def get(self):
        jsonpath_expression = parse(self.json_path)
        match = jsonpath_expression.find(self.json_data)
        source_data_value = match[0].value
        return source_data_value

# %%
class STTM:
    def __init__(self, input_json):
        self.input_json = input_json
        self.mapping_instance = Mappings()
        self.source_instance = Source()
        self.destination_instance = Target()
        self.transform_instance = Transform()
        self.look_up_mask = {i.name: i.value for i in TransformMask}
        self.json_data_transformed = {}

    def _get_mapping_data(self):
        return self.mapping_instance.get

    def _get_mapping_source_data(self):
        return self.source_instance.get

    def get_transformed_data(self):

        for mappings in self._get_mapping_data():

            """fetch the source mapping """
            mapping_source_id = mappings.get("mapping_source")
            mapping_destination_id = mappings.get("mapping_destination")
            mapping_transform_id = mappings.get("mapping_transform")

            mapping_source_data = self.source_instance.get_data_by_id(id=mapping_source_id)
            transform_data = self.transform_instance.get_data_by_id(id=mapping_transform_id)

            """Fetch Source  field Name"""
            source_field_name = mapping_source_data.get("source_field_name")

            """if field given is not present incoming json """
            if source_field_name not in self.input_json.keys():
                if mapping_source_data.get("is_required"):
                    raise Exception(
                        "Alert ! Field {} is not present in JSON please FIX mappings ".format(source_field_name))
                else:
                    pass

            else:
                source_data_value = JsonQuery(
                    json_path=mapping_source_data.get("source_field_mapping"),
                    json_data=self.input_json
                ).get()

                """check the data type for source if matches with what we have """
                if mapping_source_data.get("source_field_type") != type(source_data_value).__name__:
                    if source_data_value is not None:
                        _message = (
                            "Alert ! Source Field :{} Datatype has changed from {} to {} ".format(source_field_name,
                                                                                                  mapping_source_data.get(
                                                                                                      "source_field_type"),
                                                                                                  type(
                                                                                                      source_data_value).__name__))
                        print(_message)
                        raise Exception(_message)

                """Query and fetch the Destination | target """
                destination_mappings_json_object = self.destination_instance.get_data_by_id(
                    id=mappings.get("mapping_destination"))

                destination_field_name = destination_mappings_json_object.get("destination_field_name")
                destination_field_type = destination_mappings_json_object.get("destination_field_type")

                dtypes = [str, float, list, int, set, dict]

                for dtype in dtypes:

                    """Datatype Conversion """
                    if destination_field_type == str(dtype.__name__):

                        """is source is none insert default value"""
                        if source_data_value is None:
                            self.json_data_transformed[destination_field_name] = dtype.__call__(
                                destination_mappings_json_object.get("default_value")
                            )

                        else:
                            """check if you have items to transform"""
                            if transform_data is not None:
                                """ check for invalid mask name """
                                if transform_data.get("transform_mask") not in list(self.look_up_mask.keys()):
                                    raise Exception(
                                        f"Specified Transform {transform_data.get('transform_mask')} is not available please select from following Options :{list(self.look_up_mask.keys())}")
                                else:
                                    mask_apply = self.look_up_mask.get(transform_data.get("transform_mask"))
                                    converted_dtype = dtype.__call__(source_data_value)
                                    mask = f'converted_dtype{mask_apply}'
                                    curated_value = eval(mask)
                                    self.json_data_transformed[destination_field_name] = curated_value

                            else:
                                self.json_data_transformed[destination_field_name] = dtype.__call__(source_data_value)

        return self.json_data_transformed

# %%
transformed_data = []
for item in data:
    helper = STTM(input_json=item)
    response = helper.get_transformed_data()
    transformed_data.append(response)
    print(response)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'Title': 'Happy Anniversary', 'IMDbScore': '5.7', 'IMDbVotes': '3838', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-30', 'ProductionHouse': 'Industry Entertainment'}
# {'Title': 'Sofía Niño De Rivera: Selección Natural', 'IMDbScore': '6.8', 'IMDbVotes': '205', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-30', 'ProductionHouse': 'None'}
# {'Title': 'First Match', 'IMDbScore': '6.4', 'IMDbVotes': '1980', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-03-30', 'ProductionHouse': 'None'}
# {'Title': 'The China Hustle', 'IMDbScore': '7.2', 'IMDbVotes': '2881', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-30', 'ProductionHouse': 'Jigsaw Productions, S.J. Gibson Films, Kennedy/Marshall'}
# {'Title': 'Kill Me Heal Me', 'IMDbScore': '8.3', 'IMDbVotes': '3807', 'AwardsReceived': '8', 'NetflixReleaseDate': '2018-03-30', 'ProductionHouse': 'None'}
# {'Title': 'Historietas Assombradas: O Filme', 'IMDbScore': '6.7', 'IMDbVotes': '82', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-03-28', 'ProductionHouse': 'None'}
# {'Title': 'James Acaster: Repertoire', 'IMDbScore': '8.4', 'IMDbVotes': '2577', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-27', 'ProductionHouse': 'None'}
# {'Title': 'Birdshot', 'IMDbScore': '6.6', 'IMDbVotes': '709', 'AwardsReceived': '6', 'NetflixReleaseDate': '2018-03-26', 'ProductionHouse': 'Pelikulared'}
# {'Title': 'The Bodyguard', 'IMDbScore': '6.3', 'IMDbVotes': '120087', 'AwardsReceived': '10', 'NetflixReleaseDate': '2018-03-26', 'ProductionHouse': 'Warner Bros., Tig Productions'}
# {'Title': 'Get A Job', 'IMDbScore': '5.3', 'IMDbVotes': '21631', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-24', 'ProductionHouse': 'None'}
# {'Title': 'The Defiant Ones', 'IMDbScore': '8.5', 'IMDbVotes': '11713', 'AwardsReceived': '7', 'NetflixReleaseDate': '2018-03-23', 'ProductionHouse': 'None'}
# {'Title': 'Alexa And Katie', 'IMDbScore': '7.5', 'IMDbVotes': '3043', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-23', 'ProductionHouse': 'None'}
# {'Title': 'The Mechanism', 'IMDbScore': '8.4', 'IMDbVotes': '35473', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-23', 'ProductionHouse': 'None'}
# {'Title': 'Roxanne Roxanne', 'IMDbScore': '6.2', 'IMDbVotes': '2798', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-23', 'ProductionHouse': 'None'}
# {'Title': 'Game Over, Man!', 'IMDbScore': '5.4', 'IMDbVotes': '26414', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-23', 'ProductionHouse': 'Scott Rudin Productions'}
# {'Title': 'Layla M.', 'IMDbScore': '6.7', 'IMDbVotes': '1479', 'AwardsReceived': '6', 'NetflixReleaseDate': '2018-03-23', 'ProductionHouse': 'Chromosom Filmproduktion, Topkapi Films, Schiwago Film Gmbh'}
# {'Title': 'Secret Superstar', 'IMDbScore': '7.8', 'IMDbVotes': '20896', 'AwardsReceived': '13', 'NetflixReleaseDate': '2018-03-23', 'ProductionHouse': 'Aamir Khan Productions'}
# {'Title': 'Day And Night', 'IMDbScore': '8.3', 'IMDbVotes': '723', 'AwardsReceived': '12', 'NetflixReleaseDate': '2018-03-23', 'ProductionHouse': 'None'}
# {'Title': 'Conor Mcgregor: Notorious', 'IMDbScore': '7.2', 'IMDbVotes': '4396', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-21', 'ProductionHouse': 'Conor Mcgregor Sports &Amp; Entertainment'}
# {'Title': 'Wonder Woman', 'IMDbScore': '7.4', 'IMDbVotes': '570776', 'AwardsReceived': '24', 'NetflixReleaseDate': '2018-03-20', 'ProductionHouse': 'Atlas Entertainment, Cruel And Unusual'}
# {'Title': 'The Beatles: Eight Days A Week', 'IMDbScore': '7.8', 'IMDbVotes': '11434', 'AwardsReceived': '5', 'NetflixReleaseDate': '2018-03-17', 'ProductionHouse': 'Apple Corps, Hulu, Imagine Entertainment'}
# {'Title': 'A Man In The Dark', 'IMDbScore': '7.1', 'IMDbVotes': '223676', 'AwardsReceived': '7', 'NetflixReleaseDate': '2018-03-17', 'ProductionHouse': 'Screen Gems, Stage 6 Films, Ghost House Pictures'}
# {'Title': 'Live', 'IMDbScore': '8.4', 'IMDbVotes': '842', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-16', 'ProductionHouse': 'None'}
# {'Title': 'Wild Wild Country', 'IMDbScore': '8.2', 'IMDbVotes': '24405', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-03-16', 'ProductionHouse': 'None'}
# {'Title': 'On My Block', 'IMDbScore': '8', 'IMDbVotes': '10518', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-16', 'ProductionHouse': 'None'}
# {'Title': 'Benji', 'IMDbScore': '6.3', 'IMDbVotes': '3885', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-16', 'ProductionHouse': 'None'}
# {'Title': 'Take Your Pills', 'IMDbScore': '6.4', 'IMDbVotes': '4422', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-16', 'ProductionHouse': 'Motto Pictures'}
# {'Title': 'Little Lunch: The Halloween Horror Story', 'IMDbScore': '7.5', 'IMDbVotes': '23', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-15', 'ProductionHouse': 'None'}
# {'Title': 'Tabula Rasa', 'IMDbScore': '8.1', 'IMDbVotes': '8207', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-03-15', 'ProductionHouse': 'None'}
# {'Title': 'Pizza, Birra, Faso', 'IMDbScore': '7.1', 'IMDbVotes': '2325', 'AwardsReceived': '12', 'NetflixReleaseDate': '2018-03-15', 'ProductionHouse': 'None'}
# {'Title': 'In This Corner Of The World', 'IMDbScore': '7.8', 'IMDbVotes': '8977', 'AwardsReceived': '10', 'NetflixReleaseDate': '2018-03-15', 'ProductionHouse': 'None'}
# {'Title': 'Juni Taisen: Zodiac War', 'IMDbScore': '6.6', 'IMDbVotes': '649', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-15', 'ProductionHouse': 'None'}
# {'Title': 'Mango Dreams', 'IMDbScore': '7.5', 'IMDbVotes': '218', 'AwardsReceived': '13', 'NetflixReleaseDate': '2018-03-15', 'ProductionHouse': 'None'}
# {'Title': 'Bilu Rakkhosh', 'IMDbScore': '7.1', 'IMDbVotes': '131', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-15', 'ProductionHouse': 'None'}
# {'Title': 'The Art Of Loving', 'IMDbScore': '7.1', 'IMDbVotes': '3185', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-03-15', 'ProductionHouse': 'None'}
# {'Title': 'Secret Of The Nile', 'IMDbScore': '8.2', 'IMDbVotes': '1360', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-15', 'ProductionHouse': 'None'}
# {'Title': 'Tulip Fever', 'IMDbScore': '6.2', 'IMDbVotes': '18605', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-14', 'ProductionHouse': 'Ruby Films'}
# {'Title': 'Steel Rain', 'IMDbScore': '7.1', 'IMDbVotes': '4384', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-03-14', 'ProductionHouse': 'None'}
# {'Title': 'Ricky Gervais: Humanity', 'IMDbScore': '8', 'IMDbVotes': '15143', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-13', 'ProductionHouse': 'None'}
# {'Title': 'Annihilation', 'IMDbScore': '6.8', 'IMDbVotes': '282373', 'AwardsReceived': '16', 'NetflixReleaseDate': '2018-03-12', 'ProductionHouse': 'Scott Rudin Productions, Dna Films'}
# {'Title': 'Bad Match', 'IMDbScore': '5.5', 'IMDbVotes': '3782', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-12', 'ProductionHouse': 'Boulderlight Pictures, Orion Pictures'}
# {'Title': 'Bitch', 'IMDbScore': '5.1', 'IMDbVotes': '1735', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-12', 'ProductionHouse': 'None'}
# {'Title': 'Survival Family', 'IMDbScore': '7.2', 'IMDbVotes': '1854', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-11', 'ProductionHouse': 'None'}
# {'Title': '68 Kill', 'IMDbScore': '6', 'IMDbVotes': '4945', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-03-10', 'ProductionHouse': 'Snowfort Pictures, Ifc Films, Alliance Media Partners'}
# {'Title': 'Nocturnal Animals', 'IMDbScore': '7.5', 'IMDbVotes': '239999', 'AwardsReceived': '20', 'NetflixReleaseDate': '2018-03-10', 'ProductionHouse': 'Focus Features, Artina Films, Fade To Black Productions'}
# {'Title': 'Collateral', 'IMDbScore': '6.8', 'IMDbVotes': '13848', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-09', 'ProductionHouse': 'None'}
# {'Title': 'The Outsider', 'IMDbScore': '6.3', 'IMDbVotes': '20861', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-09', 'ProductionHouse': 'Linson Entertainment, Waypoint Entertainment'}
# {'Title': 'Ladies First', 'IMDbScore': '7.2', 'IMDbVotes': '410', 'AwardsReceived': '12', 'NetflixReleaseDate': '2018-03-08', 'ProductionHouse': 'None'}
# {'Title': 'Partition 1947', 'IMDbScore': '6.7', 'IMDbVotes': '6987', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-08', 'ProductionHouse': 'Bend It Films, Deepak Nayar'}
# {'Title': 'Aliens Ate My Homework', 'IMDbScore': '4.6', 'IMDbVotes': '1155', 'AwardsReceived': '7', 'NetflixReleaseDate': '2018-03-07', 'ProductionHouse': 'Universal 1440 Entertainment, Side Street Post, Front Street Pictures'}
# {'Title': 'Bullet Head', 'IMDbScore': '5.4', 'IMDbVotes': '8659', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-07', 'ProductionHouse': 'Saban Films, Principato-Young Entertainment'}
# {'Title': 'The Shack', 'IMDbScore': '6.3', 'IMDbVotes': '30671', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-03-06', 'ProductionHouse': 'Gil Netter, Windblown Media'}
# {'Title': 'Borderliner', 'IMDbScore': '6.8', 'IMDbVotes': '3215', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-06', 'ProductionHouse': 'None'}
# {'Title': 'A Perfect Murder', 'IMDbScore': '6.5', 'IMDbVotes': '79406', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-03-06', 'ProductionHouse': 'Warner Bros. Pictures, Kopelson Entertainment'}
# {'Title': 'Happy Family', 'IMDbScore': '7.4', 'IMDbVotes': '3161', 'AwardsReceived': '13', 'NetflixReleaseDate': '2018-03-05', 'ProductionHouse': 'None'}
# {'Title': 'B: The Beginning', 'IMDbScore': '7.2', 'IMDbVotes': '3668', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-02', 'ProductionHouse': 'None'}
# {'Title': 'Flint Town', 'IMDbScore': '7.9', 'IMDbVotes': '3209', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-02', 'ProductionHouse': 'None'}
# {'Title': 'One Week Friends', 'IMDbScore': '7', 'IMDbVotes': '967', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-02', 'ProductionHouse': 'None'}
# {'Title': 'Lucky Romance', 'IMDbScore': '7.1', 'IMDbVotes': '549', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-02', 'ProductionHouse': 'None'}
# {'Title': 'Columbus', 'IMDbScore': '7.2', 'IMDbVotes': '14556', 'AwardsReceived': '9', 'NetflixReleaseDate': '2018-03-02', 'ProductionHouse': 'Depth Of Field, Superlative Films'}
# {'Title': 'A Silent Voice', 'IMDbScore': '8.1', 'IMDbVotes': '48554', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'Loving Vincent', 'IMDbScore': '7.8', 'IMDbVotes': '50988', 'AwardsReceived': '22', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'Break Thru Films, Silver Reel, Trademark Films'}
# {'Title': 'Wind River', 'IMDbScore': '7.7', 'IMDbVotes': '207223', 'AwardsReceived': '14', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'Synergics Films, Acacia Filmed Entertainment, Star Thrower Entertainment, Riverstone Pictures, Thunder Road Pictures'}
# {'Title': 'King Arthur: Legend Of The Sword', 'IMDbScore': '6.7', 'IMDbVotes': '192987', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'Weed Road, Ritchie/Wigram, Safehouse Pictures'}
# {'Title': 'Balu Mahi', 'IMDbScore': '6.3', 'IMDbVotes': '576', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'The Silence', 'IMDbScore': '7.3', 'IMDbVotes': '275', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'Solo', 'IMDbScore': '7.1', 'IMDbVotes': '3109', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'Shubh Aarambh', 'IMDbScore': '6.9', 'IMDbVotes': '107', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'Tu Hai Mera Sunday', 'IMDbScore': '7.8', 'IMDbVotes': '1241', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'Guru', 'IMDbScore': '7.7', 'IMDbVotes': '22044', 'AwardsReceived': '17', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'Madras Talkies'}
# {'Title': 'The Silence', 'IMDbScore': 'None', 'IMDbVotes': 'None', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'G&Amp;G, Sikelia, Ylk, Efo Films'}
# {'Title': 'Kaakan', 'IMDbScore': '8', 'IMDbVotes': '51', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'Mangorange Productions'}
# {'Title': 'Bachelor Girls', 'IMDbScore': '7.2', 'IMDbVotes': '72', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'A Dogs Purpose', 'IMDbScore': '7.2', 'IMDbVotes': '65912', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'Reliance Entertainment, Universal Pictures, Walden Media, Pariah'}
# {'Title': 'Shuddhi', 'IMDbScore': '7.9', 'IMDbVotes': '367', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'Something Huge', 'IMDbScore': '4.5', 'IMDbVotes': '445', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'Dil Se', 'IMDbScore': '7.6', 'IMDbVotes': '26831', 'AwardsReceived': '11', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'None'}
# {'Title': 'Love Beats Rhymes', 'IMDbScore': '5.4', 'IMDbVotes': '881', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'Codeblack Films, Lionsgate'}
# {'Title': 'La 92', 'IMDbScore': '8.2', 'IMDbVotes': '5562', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-03-01', 'ProductionHouse': 'Lightbox Pictures'}
# {'Title': 'Kims Convenience', 'IMDbScore': '8.2', 'IMDbVotes': '8579', 'AwardsReceived': '19', 'NetflixReleaseDate': '2018-02-28', 'ProductionHouse': 'None'}
# {'Title': 'Derren Brown: The Push', 'IMDbScore': '7.5', 'IMDbVotes': '3345', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-27', 'ProductionHouse': 'None'}
# {'Title': 'Beach Rats', 'IMDbScore': '6.4', 'IMDbVotes': '12652', 'AwardsReceived': '12', 'NetflixReleaseDate': '2018-02-27', 'ProductionHouse': 'Cinereach'}
# {'Title': 'The Bridges Of Madison County', 'IMDbScore': '7.6', 'IMDbVotes': '73431', 'AwardsReceived': '7', 'NetflixReleaseDate': '2018-02-26', 'ProductionHouse': 'Warner Bros., Malpaso Company, Amblin Entertainment'}
# {'Title': 'Jeepers Creepers 3', 'IMDbScore': '3.9', 'IMDbVotes': '17415', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-25', 'ProductionHouse': 'American Zoetrope'}
# {'Title': 'Stop! Or My Mom Will Shoot', 'IMDbScore': '4.3', 'IMDbVotes': '38437', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-02-24', 'ProductionHouse': 'Universal Pictures, Northern Lights Entertainment'}
# {'Title': 'The Zookeepers Wife', 'IMDbScore': '7', 'IMDbVotes': '38813', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-02-24', 'ProductionHouse': 'Scion Films, Electric City Entertainment'}
# {'Title': 'Timeline', 'IMDbScore': '6.8', 'IMDbVotes': '336', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-23', 'ProductionHouse': 'None'}
# {'Title': 'Mute', 'IMDbScore': '5.4', 'IMDbVotes': '31113', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-23', 'ProductionHouse': 'Liberty Films Uk, Studio Babelsberg'}
# {'Title': 'Seven Seconds', 'IMDbScore': '7.7', 'IMDbVotes': '13260', 'AwardsReceived': '8', 'NetflixReleaseDate': '2018-02-23', 'ProductionHouse': 'None'}
# {'Title': 'Ugly Delicious', 'IMDbScore': '7.8', 'IMDbVotes': '3102', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-23', 'ProductionHouse': 'None'}
# {'Title': 'Lincoln', 'IMDbScore': '7.3', 'IMDbVotes': '245650', 'AwardsReceived': '109', 'NetflixReleaseDate': '2018-02-22', 'ProductionHouse': 'Amblin Entertainment, Kennedy/Marshall'}
# {'Title': 'Accident', 'IMDbScore': '6.6', 'IMDbVotes': '3005', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-22', 'ProductionHouse': 'Media Asia Films Ltd. [Hk], Milky Way Image Company'}
# {'Title': 'Churchill', 'IMDbScore': '6.1', 'IMDbVotes': '12131', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-22', 'ProductionHouse': 'Salon Pictures, Head Gear Films, Tempo Productions Limited'}
# {'Title': 'Hitlers Circle Of Evil', 'IMDbScore': '8', 'IMDbVotes': '3128', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-22', 'ProductionHouse': 'None'}
# {'Title': 'Forgotten', 'IMDbScore': '7.4', 'IMDbVotes': '18919', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-21', 'ProductionHouse': 'None'}
# {'Title': 'The Breadwinner', 'IMDbScore': '7.7', 'IMDbVotes': '20926', 'AwardsReceived': '20', 'NetflixReleaseDate': '2018-02-21', 'ProductionHouse': 'Guru Animation Studio, Aircraft Pictures, Mélusine Productions, Cartoon Saloon, Jolie Pas'}
# {'Title': 'Memoir Of A Murderer', 'IMDbScore': '7.2', 'IMDbVotes': '6393', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-20', 'ProductionHouse': 'None'}
# {'Title': 'The Frankenstein Chronicles', 'IMDbScore': '7.3', 'IMDbVotes': '9977', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-02-20', 'ProductionHouse': 'None'}
# {'Title': 'Fullmetal Alchemist', 'IMDbScore': '5.2', 'IMDbVotes': '18705', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-19', 'ProductionHouse': 'None'}
# {'Title': 'One Piece', 'IMDbScore': '6.9', 'IMDbVotes': '1637', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-19', 'ProductionHouse': 'None'}
# {'Title': 'A Week In Watts', 'IMDbScore': '6.3', 'IMDbVotes': '162', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-19', 'ProductionHouse': 'None'}
# {'Title': 'The Joel Mchale Show With Joel Mchale', 'IMDbScore': '7.2', 'IMDbVotes': '2199', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-18', 'ProductionHouse': 'None'}
# {'Title': 'The Final Year', 'IMDbScore': '6.4', 'IMDbVotes': '3106', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-18', 'ProductionHouse': 'Passion Pictures, Prettybird, Motto Pictures'}
# {'Title': 'Agustín Aristarán: Soy Rada', 'IMDbScore': '6.8', 'IMDbVotes': '93', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-17', 'ProductionHouse': 'None'}
# {'Title': 'Pettersson Und Findus', 'IMDbScore': '7.1', 'IMDbVotes': '18', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-17', 'ProductionHouse': 'None'}
# {'Title': 'Brave Miss World', 'IMDbScore': '7', 'IMDbVotes': '527', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-17', 'ProductionHouse': 'Artemis Rising Films, Reif Entertainment , Linor Documentary'}
# {'Title': 'First Team: Juventus', 'IMDbScore': '7.3', 'IMDbVotes': '1859', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-16', 'ProductionHouse': 'None'}
# {'Title': 'Everything Sucks!', 'IMDbScore': '7.5', 'IMDbVotes': '15103', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-16', 'ProductionHouse': 'None'}
# {'Title': 'John Wick: Chapter Two', 'IMDbScore': '7.5', 'IMDbVotes': '367362', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-02-16', 'ProductionHouse': 'Thunder Road Pictures, 87Eleven'}
# {'Title': 'Sword Art Online The Movie: Ordinal Scale', 'IMDbScore': '7.4', 'IMDbVotes': '6484', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-15', 'ProductionHouse': 'None'}
# {'Title': 'Reply 1988', 'IMDbScore': '9.1', 'IMDbVotes': '3434', 'AwardsReceived': '5', 'NetflixReleaseDate': '2018-02-15', 'ProductionHouse': 'None'}
# {'Title': 'Rooftop Prince', 'IMDbScore': '7.8', 'IMDbVotes': '2146', 'AwardsReceived': '11', 'NetflixReleaseDate': '2018-02-15', 'ProductionHouse': 'None'}
# {'Title': 'The Villainess', 'IMDbScore': '6.7', 'IMDbVotes': '12346', 'AwardsReceived': '6', 'NetflixReleaseDate': '2018-02-15', 'ProductionHouse': 'Apeitda'}
# {'Title': 'Gangsta.', 'IMDbScore': '7.3', 'IMDbVotes': '2082', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-15', 'ProductionHouse': 'None'}
# {'Title': 'Chris Rock: Tamborine', 'IMDbScore': '6.6', 'IMDbVotes': '6191', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-14', 'ProductionHouse': 'None'}
# {'Title': 'Love Per Square Foot', 'IMDbScore': '7.2', 'IMDbVotes': '7352', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-14', 'ProductionHouse': 'Rsvp Production'}
# {'Title': 'Trophy', 'IMDbScore': '7.3', 'IMDbVotes': '617', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-14', 'ProductionHouse': 'Candescent Films, Pulse Films'}
# {'Title': 'The Mortified Guide', 'IMDbScore': '7.9', 'IMDbVotes': '264', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-14', 'ProductionHouse': 'None'}
# {'Title': 'Burning Ice', 'IMDbScore': '7.6', 'IMDbVotes': '211', 'AwardsReceived': '8', 'NetflixReleaseDate': '2018-02-12', 'ProductionHouse': 'None'}
# {'Title': 'Breathe', 'IMDbScore': '7.2', 'IMDbVotes': '19275', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-11', 'ProductionHouse': 'Imaginarium Productions'}
# {'Title': 'Unforgettable', 'IMDbScore': '5.1', 'IMDbVotes': '13987', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-10', 'ProductionHouse': 'Warner Bros. Pictures'}
# {'Title': 'First Kill', 'IMDbScore': '5', 'IMDbVotes': '10378', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-10', 'ProductionHouse': 'Highland Film Group, Brookstreet Pictures'}
# {'Title': 'The Ritual', 'IMDbScore': '6.3', 'IMDbVotes': '78411', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-02-09', 'ProductionHouse': 'Entertainment One'}
# {'Title': 'Seeing Allred', 'IMDbScore': '6.9', 'IMDbVotes': '1007', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-09', 'ProductionHouse': 'Netflix'}
# {'Title': 'When We First Met', 'IMDbScore': '6.4', 'IMDbVotes': '42687', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-09', 'ProductionHouse': 'Wonderland Sound And Vision, Netflix, Footprint Features, Mxn Entertainment'}
# {'Title': 'The Emoji Movie', 'IMDbScore': '3.3', 'IMDbVotes': '56232', 'AwardsReceived': '7', 'NetflixReleaseDate': '2018-02-09', 'ProductionHouse': 'Sony Pictures Animation'}
# {'Title': 'Legion', 'IMDbScore': '8.2', 'IMDbVotes': '82534', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-02-09', 'ProductionHouse': 'None'}
# {'Title': 'Imposters', 'IMDbScore': '7.8', 'IMDbVotes': '10642', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-08', 'ProductionHouse': 'None'}
# {'Title': 'Ingrid Goes West', 'IMDbScore': '6.6', 'IMDbVotes': '36264', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-02-08', 'ProductionHouse': '141 Entertainment, Mighty Engine'}
# {'Title': 'Chasing Liberty', 'IMDbScore': '6.1', 'IMDbVotes': '36367', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-08', 'ProductionHouse': 'None'}
# {'Title': 'Queer Eye', 'IMDbScore': '8.5', 'IMDbVotes': '15500', 'AwardsReceived': '15', 'NetflixReleaseDate': '2018-02-07', 'ProductionHouse': 'None'}
# {'Title': 'Valor', 'IMDbScore': '8.2', 'IMDbVotes': '6', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-07', 'ProductionHouse': 'None'}
# {'Title': 'Cardboard Gangsters', 'IMDbScore': '6.4', 'IMDbVotes': '2604', 'AwardsReceived': '8', 'NetflixReleaseDate': '2018-02-06', 'ProductionHouse': 'Stalker Films'}
# {'Title': 'Fred Armisen: Standup For Drummers', 'IMDbScore': '5.8', 'IMDbVotes': '1177', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-06', 'ProductionHouse': 'None'}
# {'Title': '24: Legacy', 'IMDbScore': '6.2', 'IMDbVotes': '10116', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-06', 'ProductionHouse': 'None'}
# {'Title': 'Plan B', 'IMDbScore': '8.2', 'IMDbVotes': '139', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-05', 'ProductionHouse': 'None'}
# {'Title': 'The Cloverfield Paradox', 'IMDbScore': '5.5', 'IMDbVotes': '95755', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-05', 'ProductionHouse': 'Paramount Pictures, Bad Robot'}
# {'Title': 'Ollie And Moon', 'IMDbScore': '8.4', 'IMDbVotes': '53', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-03', 'ProductionHouse': 'None'}
# {'Title': 'Coach Snoop', 'IMDbScore': '6.8', 'IMDbVotes': '530', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-02', 'ProductionHouse': 'None'}
# {'Title': 'Altered Carbon', 'IMDbScore': '8', 'IMDbVotes': '142714', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-02-02', 'ProductionHouse': 'None'}
# {'Title': 'On Body And Soul', 'IMDbScore': '7.6', 'IMDbVotes': '24150', 'AwardsReceived': '17', 'NetflixReleaseDate': '2018-02-02', 'ProductionHouse': 'None'}
# {'Title': 'Suicide Club', 'IMDbScore': '6.6', 'IMDbVotes': '18759', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-02', 'ProductionHouse': 'None'}
# {'Title': 'El Desconocido', 'IMDbScore': '7', 'IMDbVotes': '120', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'None'}
# {'Title': 'Damnation', 'IMDbScore': '7.7', 'IMDbVotes': '6923', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'None'}
# {'Title': 'Lost City Of Z', 'IMDbScore': '6.6', 'IMDbVotes': '80547', 'AwardsReceived': '6', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'Amazon Studios/Bleecker Street Media'}
# {'Title': 'Any Given Sunday', 'IMDbScore': '6.9', 'IMDbVotes': '112334', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'Donners&#39; Company, Warner Brothers, Illusion Entertainment, Ixtlan Corporation'}
# {'Title': 'Liberated: The New Sexual Revolution', 'IMDbScore': '6', 'IMDbVotes': '1374', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'None'}
# {'Title': 'Baywatch', 'IMDbScore': '5.5', 'IMDbVotes': '162201', 'AwardsReceived': '5', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'Cold Spring Pictures, Paramount Pictures, Seven Bucks Productions, Contrafilm'}
# {'Title': 'Transformers: The Last Knight', 'IMDbScore': '5.2', 'IMDbVotes': '136008', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'Di Bonaventura Pictures, Tom Desanto/Don Murphy, Ian Bryce Productions'}
# {'Title': 'The Avengers', 'IMDbScore': '3.8', 'IMDbVotes': '41038', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'Warner Brothers'}
# {'Title': 'Männerherzen', 'IMDbScore': '6.2', 'IMDbVotes': '4853', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'Wiedemann &Amp; Berg Filmproduktion'}
# {'Title': 'Newness', 'IMDbScore': '6.3', 'IMDbVotes': '14019', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-02-01', 'ProductionHouse': 'None'}
# {'Title': 'Going In Style', 'IMDbScore': '6.6', 'IMDbVotes': '77104', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-31', 'ProductionHouse': 'Warner Brothers/Seven Arts'}
# {'Title': 'Babylon Berlin', 'IMDbScore': '8.4', 'IMDbVotes': '19122', 'AwardsReceived': '22', 'NetflixReleaseDate': '2018-01-31', 'ProductionHouse': 'None'}
# {'Title': 'Jerry Seinfeld: Im Telling You For The Last Time', 'IMDbScore': '7.9', 'IMDbVotes': '5336', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-30', 'ProductionHouse': 'None'}
# {'Title': 'One Of Us', 'IMDbScore': '7', 'IMDbVotes': '6579', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-30', 'ProductionHouse': 'None'}
# {'Title': 'Mau Nieto: Viviendo Sobrio… Desde El Bar', 'IMDbScore': '6.6', 'IMDbVotes': '68', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-26', 'ProductionHouse': 'None'}
# {'Title': 'Dirty Money', 'IMDbScore': '8.2', 'IMDbVotes': '12', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-26', 'ProductionHouse': 'None'}
# {'Title': 'A Futile And Stupid Gesture', 'IMDbScore': '6.8', 'IMDbVotes': '14021', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-26', 'ProductionHouse': 'Principato-Young Entertainment, Abominable Pictures'}
# {'Title': 'Acts Of Vengeance', 'IMDbScore': '5.7', 'IMDbVotes': '10489', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-25', 'ProductionHouse': 'Nu Boyana Film Studios'}
# {'Title': 'Todd Glass: Act Happy', 'IMDbScore': '5.1', 'IMDbVotes': '335', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-23', 'ProductionHouse': 'Netflix'}
# {'Title': 'Black Lightning', 'IMDbScore': '6.1', 'IMDbVotes': '21638', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-23', 'ProductionHouse': 'None'}
# {'Title': 'Shining Inheritance', 'IMDbScore': '7.7', 'IMDbVotes': '693', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-01-20', 'ProductionHouse': 'None'}
# {'Title': 'The Open House', 'IMDbScore': '3.2', 'IMDbVotes': '31203', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-19', 'ProductionHouse': 'None'}
# {'Title': 'Kakegurui', 'IMDbScore': '6.7', 'IMDbVotes': '660', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-18', 'ProductionHouse': 'None'}
# {'Title': 'Bad Day For The Cut', 'IMDbScore': '6.5', 'IMDbVotes': '6344', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-18', 'ProductionHouse': 'Six Mile Hill Productions'}
# {'Title': 'Death March To The Parallel World Rhapsody', 'IMDbScore': '6.6', 'IMDbVotes': '1148', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-17', 'ProductionHouse': 'None'}
# {'Title': 'Born To Be Blue', 'IMDbScore': '6.9', 'IMDbVotes': '8053', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-01-17', 'ProductionHouse': 'None'}
# {'Title': 'Godzilla', 'IMDbScore': '6', 'IMDbVotes': '7600', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-17', 'ProductionHouse': 'None'}
# {'Title': 'Found', 'IMDbScore': '5.9', 'IMDbVotes': '3814', 'AwardsReceived': '25', 'NetflixReleaseDate': '2018-01-15', 'ProductionHouse': 'Forbidden Films'}
# {'Title': 'The Girl On The Train', 'IMDbScore': '6.5', 'IMDbVotes': '169614', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-01-15', 'ProductionHouse': 'Sony Classical, Universal Pictures, Reliance Entertainment, Marc Platt Productions'}
# {'Title': 'Earth To Luna!', 'IMDbScore': '7.5', 'IMDbVotes': '46', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-15', 'ProductionHouse': 'None'}
# {'Title': 'My Tomorrow, Your Yesterday', 'IMDbScore': '7.5', 'IMDbVotes': '3554', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-14', 'ProductionHouse': 'None'}
# {'Title': 'Ghostbusters', 'IMDbScore': '6.4', 'IMDbVotes': '204928', 'AwardsReceived': '5', 'NetflixReleaseDate': '2018-01-13', 'ProductionHouse': 'Ivan Reitman'}
# {'Title': 'Home Again', 'IMDbScore': '5.8', 'IMDbVotes': '28629', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-13', 'ProductionHouse': 'Black Bicycle Entertainment, Waverly Films'}
# {'Title': 'The Polka King', 'IMDbScore': '5.9', 'IMDbVotes': '9121', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-12', 'ProductionHouse': 'Red Hour Films, Electric Dynamite, Permut Presentations'}
# {'Title': 'Tom Segura: Disgraceful', 'IMDbScore': '7.6', 'IMDbVotes': '3098', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-12', 'ProductionHouse': 'None'}
# {'Title': 'My Next Guest Needs No Introduction With David Letterman', 'IMDbScore': '7.9', 'IMDbVotes': '4761', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-12', 'ProductionHouse': 'None'}
# {'Title': 'Somebody Feed Phil', 'IMDbScore': '8.2', 'IMDbVotes': '3540', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-12', 'ProductionHouse': 'None'}
# {'Title': 'A Storks Journey', 'IMDbScore': '5.8', 'IMDbVotes': '1789', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-12', 'ProductionHouse': 'None'}
# {'Title': 'Mobile Suit Z Gundam: A New Translation - Heirs To The Stars', 'IMDbScore': '6.8', 'IMDbVotes': '193', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-12', 'ProductionHouse': 'None'}
# {'Title': 'Rage Of Bahamut: Genesis', 'IMDbScore': '7.4', 'IMDbVotes': '1240', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-12', 'ProductionHouse': 'None'}
# {'Title': 'Mob Psycho 100', 'IMDbScore': '8.5', 'IMDbVotes': '15631', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-01-12', 'ProductionHouse': 'None'}
# {'Title': 'Mobile Suit Z Gundam Iii: Love Is The Pulse Of The Stars', 'IMDbScore': '6.7', 'IMDbVotes': '202', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-12', 'ProductionHouse': 'None'}
# {'Title': 'Violet Evergarden', 'IMDbScore': '8.4', 'IMDbVotes': '12045', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-11', 'ProductionHouse': 'None'}
# {'Title': 'Captain Underpants: The First Epic Movie', 'IMDbScore': '6.2', 'IMDbVotes': '25081', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-01-11', 'ProductionHouse': 'Dreamworks Animation, Mikros Image, Scholastic Entertainment Inc.'}
# {'Title': 'Good Time', 'IMDbScore': '7.4', 'IMDbVotes': '91250', 'AwardsReceived': '6', 'NetflixReleaseDate': '2018-01-11', 'ProductionHouse': 'Elara Pictures, Rhea Films'}
# {'Title': 'The House Next Door', 'IMDbScore': '6.8', 'IMDbVotes': '2042', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-08', 'ProductionHouse': 'None'}
# {'Title': 'The Untold Tales Of Armistead Maupin', 'IMDbScore': '7.6', 'IMDbVotes': '535', 'AwardsReceived': '5', 'NetflixReleaseDate': '2018-01-08', 'ProductionHouse': 'Dodgeville Films, Tigerlily Pictures Llc'}
# {'Title': 'Pop Team Epic', 'IMDbScore': '6.8', 'IMDbVotes': '626', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-07', 'ProductionHouse': 'None'}
# {'Title': 'Julian Schnabel: A Private Portrait', 'IMDbScore': '6.6', 'IMDbVotes': '201', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-07', 'ProductionHouse': 'Cohen Media Group'}
# {'Title': 'A Bad Moms Christmas', 'IMDbScore': '5.6', 'IMDbVotes': '45151', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-06', 'ProductionHouse': 'Huayi Brothers Pictures'}
# {'Title': 'Rotten', 'IMDbScore': '7', 'IMDbVotes': '87', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-05', 'ProductionHouse': 'None'}
# {'Title': 'Comedians In Cars Getting Coffee', 'IMDbScore': '8.1', 'IMDbVotes': '11079', 'AwardsReceived': '11', 'NetflixReleaseDate': '2018-01-05', 'ProductionHouse': 'None'}
# {'Title': 'Devilman Crybaby', 'IMDbScore': '7.6', 'IMDbVotes': '12797', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-01-05', 'ProductionHouse': 'None'}
# {'Title': 'The End Of The F***Ing World', 'IMDbScore': '8.1', 'IMDbVotes': '146188', 'AwardsReceived': '9', 'NetflixReleaseDate': '2018-01-05', 'ProductionHouse': 'None'}
# {'Title': 'Time Renegades', 'IMDbScore': '6.8', 'IMDbVotes': '937', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-05', 'ProductionHouse': 'None'}
# {'Title': 'That Winter, The Wind Blows', 'IMDbScore': '7.7', 'IMDbVotes': '1418', 'AwardsReceived': '7', 'NetflixReleaseDate': '2018-01-05', 'ProductionHouse': 'None'}
# {'Title': 'She Was Pretty', 'IMDbScore': '7.7', 'IMDbVotes': '3617', 'AwardsReceived': '4', 'NetflixReleaseDate': '2018-01-05', 'ProductionHouse': 'None'}
# {'Title': 'The Truth Beneath', 'IMDbScore': '6.8', 'IMDbVotes': '1112', 'AwardsReceived': '11', 'NetflixReleaseDate': '2018-01-04', 'ProductionHouse': 'None'}
# {'Title': 'Wonderful Nightmare', 'IMDbScore': '7.1', 'IMDbVotes': '786', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-04', 'ProductionHouse': 'None'}
# {'Title': 'Blood Father', 'IMDbScore': '6.4', 'IMDbVotes': '59808', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-04', 'ProductionHouse': 'Why Not Productions, Wild Bunch'}
# {'Title': 'Roald Dahls Esio Trot', 'IMDbScore': '7', 'IMDbVotes': '4590', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-04', 'ProductionHouse': 'Bbc'}
# {'Title': 'Ask The Sexpert', 'IMDbScore': '7.6', 'IMDbVotes': '157', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-04', 'ProductionHouse': 'Coast To Coast Films'}
# {'Title': 'Hubert Und Staller: Die Ins Gras Beissen', 'IMDbScore': '7.2', 'IMDbVotes': '123', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-04', 'ProductionHouse': 'None'}
# {'Title': 'A Ghost Story', 'IMDbScore': '6.9', 'IMDbVotes': '61150', 'AwardsReceived': '12', 'NetflixReleaseDate': '2018-01-03', 'ProductionHouse': 'Scared Sheetless'}
# {'Title': 'Suffragette', 'IMDbScore': '6.9', 'IMDbVotes': '38489', 'AwardsReceived': '17', 'NetflixReleaseDate': '2018-01-03', 'ProductionHouse': 'Ruby Films'}
# {'Title': 'The Shallows', 'IMDbScore': '6.3', 'IMDbVotes': '120760', 'AwardsReceived': '1', 'NetflixReleaseDate': '2018-01-02', 'ProductionHouse': 'Weimaraner Republic Pictures, Ombra Films'}
# {'Title': 'Money Monster', 'IMDbScore': '6.5', 'IMDbVotes': '94663', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-02', 'ProductionHouse': 'Smokehouse, Allegiance Theater'}
# {'Title': 'Cant Cope, Wont Cope', 'IMDbScore': '7.3', 'IMDbVotes': '783', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-02', 'ProductionHouse': 'None'}
# {'Title': 'Aval', 'IMDbScore': '6.8', 'IMDbVotes': '2042', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-02', 'ProductionHouse': 'None'}
# {'Title': 'Mustang Island', 'IMDbScore': '6.2', 'IMDbVotes': '385', 'AwardsReceived': '2', 'NetflixReleaseDate': '2018-01-02', 'ProductionHouse': 'None'}
# {'Title': 'Die Hard 4.0', 'IMDbScore': '7.1', 'IMDbVotes': '390192', 'AwardsReceived': '3', 'NetflixReleaseDate': '2018-01-01', 'ProductionHouse': '20Th Century Fox, Dune, Cheyenne Enterprises'}
# {'Title': 'Almost Christmas', 'IMDbScore': '6.1', 'IMDbVotes': '6197', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-01', 'ProductionHouse': 'Universal Pictures, Perfect World Pictures, Will Packer Productions'}
# {'Title': 'An Ordinary Man', 'IMDbScore': '5.5', 'IMDbVotes': '1838', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-01', 'ProductionHouse': 'Enderby Entertainment, Reveal Entertainment'}
# {'Title': 'The Last: Naruto The Movie', 'IMDbScore': '7.6', 'IMDbVotes': '11418', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-01', 'ProductionHouse': 'Tv Tokyo, Shueisha, Pierrot'}
# {'Title': 'Boruto: Naruto The Movie', 'IMDbScore': '7.9', 'IMDbVotes': '8520', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-01', 'ProductionHouse': 'Tv Tokyo, Shueisha, Pierrot'}
# {'Title': 'We Speak Dance', 'IMDbScore': '7.6', 'IMDbVotes': '129', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2018-01-01', 'ProductionHouse': 'None'}
# {'Title': 'The Bleeder', 'IMDbScore': '6.5', 'IMDbVotes': '5709', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-31', 'ProductionHouse': 'Campbell Grobman Films, Jeff Rice Films, Mandalay Sports Media'}
# {'Title': 'Origin Wars', 'IMDbScore': '5.6', 'IMDbVotes': '7586', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-31', 'ProductionHouse': 'None'}
# {'Title': 'The Man With The Iron Heart', 'IMDbScore': '6.4', 'IMDbVotes': '14289', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-31', 'ProductionHouse': 'Red Crown Productions, Echo Lake Entertainment, Nexus Factory, Cutting Edge Entertainment'}
# {'Title': 'Unlocked', 'IMDbScore': '6.3', 'IMDbVotes': '30119', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-31', 'ProductionHouse': 'Silver Reel, Lipsync Productions, Bloom, Di Bonaventura Pictures, Czech Anglo Productions, Sra Productions'}
# {'Title': 'The Worlds Most Extraordinary Homes', 'IMDbScore': '7.6', 'IMDbVotes': '2878', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-31', 'ProductionHouse': 'None'}
# {'Title': 'Life Without Principle', 'IMDbScore': '6.9', 'IMDbVotes': '2103', 'AwardsReceived': '17', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'Milky Way Image'}
# {'Title': 'Protégé', 'IMDbScore': '7.2', 'IMDbVotes': '4823', 'AwardsReceived': '7', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Tatsumi', 'IMDbScore': '7.1', 'IMDbVotes': '702', 'AwardsReceived': '3', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Rurouni Kenshin: Shin Kyoto-Hen', 'IMDbScore': '7.8', 'IMDbVotes': '863', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'The Accidental Detective', 'IMDbScore': '6.7', 'IMDbVotes': '819', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Cest Si Bon', 'IMDbScore': '6', 'IMDbVotes': '358', 'AwardsReceived': '1', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Kinmoza!', 'IMDbScore': '6.7', 'IMDbVotes': '162', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Boomerang Family', 'IMDbScore': '6.5', 'IMDbVotes': '239', 'AwardsReceived': '1', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'The Sion Sono', 'IMDbScore': '6.6', 'IMDbVotes': '84', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'The Advocate: A Missing Body', 'IMDbScore': '6.6', 'IMDbVotes': '473', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Date A Live', 'IMDbScore': '7', 'IMDbVotes': '2160', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Her Father, My Lover', 'IMDbScore': '6.6', 'IMDbVotes': '16', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Thread Of Lies', 'IMDbScore': '6.7', 'IMDbVotes': '624', 'AwardsReceived': '1', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Goon: Last Of The Enforcers', 'IMDbScore': '5.8', 'IMDbVotes': '12251', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'No Trace Camping, Caramel Films'}
# {'Title': 'Snow White With The Red Hair', 'IMDbScore': '7.8', 'IMDbVotes': '1897', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Remember You', 'IMDbScore': '6.6', 'IMDbVotes': '456', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'A Certain Scientific Railgun', 'IMDbScore': '7.5', 'IMDbVotes': '1135', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Relife', 'IMDbScore': '7.8', 'IMDbVotes': '3039', 'AwardsReceived': '1', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'The Eccentric Family', 'IMDbScore': '7.6', 'IMDbVotes': '328', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Seraph Of The End', 'IMDbScore': '7.5', 'IMDbVotes': '3437', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Royal Space Force: Wings Of Honneamise', 'IMDbScore': '7.3', 'IMDbVotes': '4859', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Nisekoi', 'IMDbScore': '7.2', 'IMDbVotes': '2460', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Maoyu: Archenemy And Hero', 'IMDbScore': '7', 'IMDbVotes': '411', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Lucky Star', 'IMDbScore': '7.3', 'IMDbVotes': '1943', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Lost Highway', 'IMDbScore': '7.6', 'IMDbVotes': '131838', 'AwardsReceived': '4', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'October Films, Lost Highway Productions, Asymmetrical Productions'}
# {'Title': 'Girls Last Tour', 'IMDbScore': '7.6', 'IMDbVotes': '767', 'AwardsReceived': '1', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Children Of The Whales', 'IMDbScore': '7.1', 'IMDbVotes': '1293', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Jormungand', 'IMDbScore': '7.5', 'IMDbVotes': '987', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Inu X Boku Secret Service', 'IMDbScore': '7.1', 'IMDbVotes': '1289', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Italian Race', 'IMDbScore': '7.3', 'IMDbVotes': '4585', 'AwardsReceived': '12', 'NetflixReleaseDate': '2017-12-30', 'ProductionHouse': 'None'}
# {'Title': 'Gamers!', 'IMDbScore': '6.6', 'IMDbVotes': '953', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Gosick', 'IMDbScore': '7.4', 'IMDbVotes': '1012', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Coin Locker Girl', 'IMDbScore': '6.8', 'IMDbVotes': '1606', 'AwardsReceived': '10', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'Cj Entertainment'}
# {'Title': 'The Testament Of Sister New Devil', 'IMDbScore': '6.7', 'IMDbVotes': '1628', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Himouto! Umaru-Chan', 'IMDbScore': '7', 'IMDbVotes': '1036', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Shimoneta: A Boring World Where The Concept Of Dirty Jokes Doesnt Exist', 'IMDbScore': '7.1', 'IMDbVotes': '1501', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'A Certain Scientific Railgun Ova', 'IMDbScore': '7.5', 'IMDbVotes': '1135', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Crisis: Special Security Squad', 'IMDbScore': '7.1', 'IMDbVotes': '193', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Ballet Boys', 'IMDbScore': '7.4', 'IMDbVotes': '275', 'AwardsReceived': '3', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'Indiefilm'}
# {'Title': 'The Brand New Testament', 'IMDbScore': '7.1', 'IMDbVotes': '30082', 'AwardsReceived': '14', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'Orange Studio, Orange Cinéma Séries, Après Le Déluge, Voo, Rtbf, Climax Films, Betv, Terra Incognita Films, Juliette Films, Bnp Paribas Fortis Film Fund, Caviar Films'}
# {'Title': 'Baka And Test', 'IMDbScore': '7.3', 'IMDbVotes': '1164', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'In The Realm Of The Senses', 'IMDbScore': '6.6', 'IMDbVotes': '18473', 'AwardsReceived': '4', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'Argos Films, Shibata Organisation Inc. [Jp], Oshima Productions'}
# {'Title': 'New Atashinchi', 'IMDbScore': '7.5', 'IMDbVotes': '58', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'A Girl At My Door', 'IMDbScore': '6.9', 'IMDbVotes': '2427', 'AwardsReceived': '9', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Voice Of A Murderer', 'IMDbScore': '6.8', 'IMDbVotes': '1728', 'AwardsReceived': '1', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Ghost In The Shell: Solid State Society', 'IMDbScore': '8', 'IMDbVotes': '6641', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'Production I.G.'}
# {'Title': 'Galaxy Express 999', 'IMDbScore': '7.4', 'IMDbVotes': '1881', 'AwardsReceived': '1', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'Toei Animation Company'}
# {'Title': 'Super Mario Bros.', 'IMDbScore': '4.1', 'IMDbVotes': '48890', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'Allied Filmmakers, Hollywood Pictures, Cinergi Pictures Entertainment'}
# {'Title': 'Creepy', 'IMDbScore': '6.3', 'IMDbVotes': '4391', 'AwardsReceived': '3', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'Asmik Ace Entertainment'}
# {'Title': 'Terrace House: Opening New Doors', 'IMDbScore': '7.8', 'IMDbVotes': '804', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Shirobako', 'IMDbScore': '8.1', 'IMDbVotes': '761', 'AwardsReceived': '1', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'Kamen Rider 555: Paradise Lost', 'IMDbScore': '7.1', 'IMDbVotes': '109', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# {'Title': 'March Comes In Like A Lion', 'IMDbScore': '8.4', 'IMDbVotes': '1661', 'AwardsReceived': '1', 'NetflixReleaseDate': '2017-12-29', 'ProductionHouse': 'None'}
# ...
# {'Title': 'The Adventures Of Puss In Boots', 'IMDbScore': '6.7', 'IMDbVotes': '1383', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'All Hail King Julien', 'IMDbScore': '7.2', 'IMDbVotes': '1553', 'AwardsReceived': '5', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'The Perks Of Being A Wallflower', 'IMDbScore': '8', 'IMDbVotes': '463476', 'AwardsReceived': '19', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Mr. Mudd'}
# {'Title': 'Gossip Girl', 'IMDbScore': '7.4', 'IMDbVotes': '154652', 'AwardsReceived': '21', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Mr. Peabody And Sherman', 'IMDbScore': '6.8', 'IMDbVotes': '62677', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Pdi, Bullwinkle Studios, Dreamworks Animation'}
# {'Title': 'Instructions Not Included', 'IMDbScore': '7.5', 'IMDbVotes': '29197', 'AwardsReceived': '5', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Alebrije Cine Y Video'}
# {'Title': 'Archer', 'IMDbScore': '8.6', 'IMDbVotes': '137699', 'AwardsReceived': '13', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Amelie', 'IMDbScore': '8.3', 'IMDbVotes': '704771', 'AwardsReceived': '59', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Mmc Independent Gmbh, Tapioca Films, Mmc Independent, France 3 Cinéma, Ugc'}
# {'Title': 'Adventure Time', 'IMDbScore': '8.6', 'IMDbVotes': '76936', 'AwardsReceived': '26', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'American Pie', 'IMDbScore': '7', 'IMDbVotes': '376974', 'AwardsReceived': '9', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Summit Entertainment, Universal Pictures, Newmarket Capital Group, Zide-Perry Productions'}
# {'Title': 'Americas Next Top Model', 'IMDbScore': '5.5', 'IMDbVotes': '17193', 'AwardsReceived': '6', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Arrow', 'IMDbScore': '7.5', 'IMDbVotes': '407581', 'AwardsReceived': '22', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Avatar: The Last Airbender', 'IMDbScore': '9.2', 'IMDbVotes': '248384', 'AwardsReceived': '9', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Around The World In 80 Days', 'IMDbScore': '5.9', 'IMDbVotes': '85372', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Walt Disney Pictures, Spanknyce Films, Walden Media'}
# {'Title': 'Cj7', 'IMDbScore': '6.4', 'IMDbVotes': '14597', 'AwardsReceived': '5', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Columbia Pictures Film Production Asia'}
# {'Title': 'Seven Years In Tibet', 'IMDbScore': '7.1', 'IMDbVotes': '130041', 'AwardsReceived': '3', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Mandalay Pictures, Tristar Pictures'}
# {'Title': 'Seven Psychopaths', 'IMDbScore': '7.2', 'IMDbVotes': '241704', 'AwardsReceived': '3', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Blueprint Productions'}
# {'Title': 'Seven', 'IMDbScore': '8.6', 'IMDbVotes': '1452916', 'AwardsReceived': '29', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'New Line Cinema'}
# {'Title': 'Seven Pounds', 'IMDbScore': '7.6', 'IMDbVotes': '287555', 'AwardsReceived': '5', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Overbrook Entertainment, Escape Artists'}
# {'Title': 'The 6Th Day', 'IMDbScore': '5.9', 'IMDbVotes': '116685', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Phoenix Pictures'}
# {'Title': 'Seal Team Six: The Raid On Osama Bin Laden', 'IMDbScore': '5.7', 'IMDbVotes': '10075', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Weinstein Company'}
# {'Title': 'Hank: Five Years From The Brink', 'IMDbScore': '6.6', 'IMDbVotes': '467', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Rocky V', 'IMDbScore': '5.3', 'IMDbVotes': '127334', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'United Artists'}
# {'Title': 'Scary Movie 5', 'IMDbScore': '3.5', 'IMDbVotes': '66185', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Brad Grey Productions, Dimension Films'}
# {'Title': 'Planet 51', 'IMDbScore': '6', 'IMDbVotes': '50931', 'AwardsReceived': '4', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Ilion Animation Studios'}
# {'Title': 'Rocky Iv', 'IMDbScore': '6.9', 'IMDbVotes': '187921', 'AwardsReceived': '9', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Metro-Goldwyn-Mayer, United Artists'}
# {'Title': 'The Blacklist', 'IMDbScore': '8', 'IMDbVotes': '198574', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Crouching Tiger, Hidden Dragon', 'IMDbScore': '7.8', 'IMDbVotes': '253700', 'AwardsReceived': '102', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'United China Vision, Asia Union Film &Amp; Entertainment Ltd., China Film Co-Production Corporation, Sony Pictures Classics, Edko Films, Good Machine, Columbia Pictures Film Production Asia'}
# {'Title': 'Breaking Bad', 'IMDbScore': '9.5', 'IMDbVotes': '1469976', 'AwardsReceived': '152', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Hitch', 'IMDbScore': '6.6', 'IMDbVotes': '296596', 'AwardsReceived': '4', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Columbia Pictures, Overbrook Entertainment'}
# {'Title': 'Marco Polo', 'IMDbScore': '8', 'IMDbVotes': '64665', 'AwardsReceived': '3', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'House Of Cards', 'IMDbScore': '8.7', 'IMDbVotes': '466163', 'AwardsReceived': '34', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Inuyasha: The Movie 4: Fire On The Mystic Island', 'IMDbScore': '7.3', 'IMDbVotes': '1622', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Shogakukan'}
# {'Title': 'The 4400', 'IMDbScore': '7.3', 'IMDbVotes': '42379', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Open Season 3', 'IMDbScore': '5.1', 'IMDbVotes': '10223', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Sony Pictures Animation, Reel Fx Creative Studios'}
# {'Title': 'Blade: Trinity', 'IMDbScore': '5.9', 'IMDbVotes': '166376', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Shawn Danielle Production Services'}
# {'Title': 'Hostel: Part Iii', 'IMDbScore': '4.6', 'IMDbVotes': '28573', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Raw Nerve, Stage 6 Films'}
# {'Title': 'Rocky Iii', 'IMDbScore': '6.8', 'IMDbVotes': '175037', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'United Artists'}
# {'Title': 'Scary Movie 3', 'IMDbScore': '5.5', 'IMDbVotes': '137776', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Dimension Films, Miramax, Brad Grey Productions'}
# {'Title': 'Inuyasha: The Movie 3: Swords Of An Honorable Ruler', 'IMDbScore': '7.7', 'IMDbVotes': '2006', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Viz Media'}
# {'Title': 'Spy Kids 3: Game Over', 'IMDbScore': '4.3', 'IMDbVotes': '55368', 'AwardsReceived': '3', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Troublemaker Studios'}
# {'Title': 'The Next Three Days', 'IMDbScore': '7.3', 'IMDbVotes': '185131', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Hwy 61 Films, Lionsgate Films'}
# {'Title': '300', 'IMDbScore': '7.5', 'IMDbVotes': '918', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Free Willy 2: The Adventure Home', 'IMDbScore': '5.1', 'IMDbVotes': '17181', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Warner Brothers, Regency Enterprises'}
# {'Title': 'Miss Congeniality 2: Armed And Fabulous', 'IMDbScore': '5.1', 'IMDbVotes': '69874', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Fortis Films'}
# {'Title': 'Ong Bak 2: The Beginning', 'IMDbScore': '6.2', 'IMDbVotes': '29380', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Blade 2', 'IMDbScore': '6.7', 'IMDbVotes': '200157', 'AwardsReceived': '6', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Amen Ra Films, Imaginary Forces'}
# {'Title': 'The Lord Of The Rings: The Two Towers', 'IMDbScore': '8.7', 'IMDbVotes': '1488712', 'AwardsReceived': '126', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'New Line Cinema, Saul Zaentz Company'}
# {'Title': 'Stuart Little 2', 'IMDbScore': '5.5', 'IMDbVotes': '50515', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Colgems Productions Limited, Columbia Pictures, Franklin/Waterman Prod., Red Wagon Productions'}
# {'Title': 'Rocky Ii', 'IMDbScore': '7.3', 'IMDbVotes': '192579', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Chartoff-Winkler Productions'}
# {'Title': 'The Grudge 2', 'IMDbScore': '5.1', 'IMDbVotes': '47309', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Vertigo, Ghost House Pictures, Mandate Pictures, Columbia Pictures Corporation'}
# {'Title': 'Ip Man 2', 'IMDbScore': '7.5', 'IMDbVotes': '98175', 'AwardsReceived': '6', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Bad Boys Ii', 'IMDbScore': '6.6', 'IMDbVotes': '232260', 'AwardsReceived': '5', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Columbia'}
# {'Title': 'Scary Movie 2', 'IMDbScore': '5.3', 'IMDbVotes': '149993', 'AwardsReceived': '3', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Gold/Miller Productions, Brad Grey Productions, Wayan Bros. Entertainment'}
# {'Title': 'Dreamworks Spooky Stories: Volume 2', 'IMDbScore': '6.7', 'IMDbVotes': '447', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Fox'}
# {'Title': 'Spy Kids 2: The Island Of Lost Dreams', 'IMDbScore': '5.2', 'IMDbVotes': '61045', 'AwardsReceived': '3', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Dimension Films, Troublemaker Studios'}
# {'Title': 'Sex And The City 2', 'IMDbScore': '4.5', 'IMDbVotes': '74543', 'AwardsReceived': '8', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Darren Star'}
# {'Title': 'The Twilight Saga: Breaking Dawn: Part 2', 'IMDbScore': '5.5', 'IMDbVotes': '231863', 'AwardsReceived': '21', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Temple Hill'}
# {'Title': 'A Haunted House 2', 'IMDbScore': '4.7', 'IMDbVotes': '19835', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Baby Way'}
# {'Title': 'Inuyasha: The Movie 2: The Castle Beyond The Looking Glass', 'IMDbScore': '7.5', 'IMDbVotes': '1911', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Sunrise, Yomiuri Telecasting Corporation'}
# {'Title': 'Teenage Mutant Ninja Turtles Ii: The Secret Of The Ooze', 'IMDbScore': '6.1', 'IMDbVotes': '51714', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'New Line Cinema, Northshore Investments Ltd.'}
# {'Title': 'Never Back Down 2: The Beatdown', 'IMDbScore': '5.7', 'IMDbVotes': '18065', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Mandalay Pictures'}
# {'Title': 'Hunter X Hunter (2011)', 'IMDbScore': '8.9', 'IMDbVotes': '58141', 'AwardsReceived': '2', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Two And A Half Men', 'IMDbScore': '7', 'IMDbVotes': '241338', 'AwardsReceived': '30', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'A 2Nd Chance', 'IMDbScore': '4.7', 'IMDbVotes': '853', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'The Other One: The Long Strange Trip Of Bob Weir', 'IMDbScore': '7.3', 'IMDbVotes': '1414', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': '2012', 'IMDbScore': '5.8', 'IMDbVotes': '353917', 'AwardsReceived': '5', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Centropolis Entertainment'}
# {'Title': 'Chelsea Peretti: One Of The Greats', 'IMDbScore': '7', 'IMDbVotes': '2183', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Netflix'}
# {'Title': 'Stargate Sg-1', 'IMDbScore': '8.4', 'IMDbVotes': '83876', 'AwardsReceived': '18', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'אוקטובר 1', 'IMDbScore': '6.6', 'IMDbVotes': '334', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': '3:10 To Yuma', 'IMDbScore': '7.7', 'IMDbVotes': '289344', 'AwardsReceived': '3', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Lionsgate Films'}
# {'Title': 'Inazuma Eleven', 'IMDbScore': '8', 'IMDbVotes': '1055', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'One Direction: This Is Us', 'IMDbScore': '4.3', 'IMDbVotes': '23617', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Syco Entertainment, Modest! Management'}
# {'Title': '50 First Dates', 'IMDbScore': '6.8', 'IMDbVotes': '327916', 'AwardsReceived': '6', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Columbia Pictures Corporation, Flower Films, Anonymous Content, Happy Madison Productions'}
# {'Title': '21', 'IMDbScore': '6.8', 'IMDbVotes': '230337', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Trigger Street Productions, Michael De Luca'}
# {'Title': 'Year One', 'IMDbScore': '4.9', 'IMDbVotes': '92364', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Ocean Pictures, Apatow Company'}
# {'Title': 'One Chance', 'IMDbScore': '6.8', 'IMDbVotes': '11536', 'AwardsReceived': '3', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Relevant Entertainment, Weston Pictures'}
# {'Title': 'The Twilight Saga: Breaking Dawn: Part 1', 'IMDbScore': '4.9', 'IMDbVotes': '224372', 'AwardsReceived': '11', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Temple Hill'}
# {'Title': 'One For The Money', 'IMDbScore': '5.3', 'IMDbVotes': '40841', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Lakeshore Entertainment, Sidney Kimmel Entertainment'}
# {'Title': '4.3.2.1', 'IMDbScore': '5.8', 'IMDbVotes': '10370', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Unstoppable Entertainment, Atlantic Swiss Productions, Retro-Juice Productions'}
# {'Title': '13', 'IMDbScore': '6.1', 'IMDbVotes': '40425', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Overnight Films'}
# {'Title': 'District 13: Ultimatum', 'IMDbScore': '6.5', 'IMDbVotes': '42967', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': '13 Going On 30', 'IMDbScore': '6.2', 'IMDbVotes': '167842', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'Revolution Studios, Thirteen Productions Llc'}
# {'Title': 'Life 2.0', 'IMDbScore': '6.2', 'IMDbVotes': '878', 'AwardsReceived': '1', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Brand New Day', 'IMDbScore': '7.3', 'IMDbVotes': '14', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Daniel Arends: Blessuretijd', 'IMDbScore': '7.8', 'IMDbVotes': '174', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}
# {'Title': 'Dreamworks Happy Holidays From Madagascar', 'IMDbScore': '6.8', 'IMDbVotes': '71', 'AwardsReceived': 'None', 'NetflixReleaseDate': '2015-04-14', 'ProductionHouse': 'None'}

# %%
pd.DataFrame(transformed_data)
# Out:
#                                           Title IMDbScore IMDbVotes  \
# 0                              Lets Fight Ghost       7.9    205926
# 1                           How To Build A Girl       5.8      2838
# 2                              The Con-Heartist       7.4       131
# 3                                  Gleboka Woda       7.5        47
# 4                                 Only A Mother       6.7        88
# ...                                         ...       ...       ...
# 9420                             13 Going On 30       6.2    167842
# 9421                                   Life 2.0       6.2       878
# 9422                              Brand New Day       7.3        14
# 9423                Daniel Arends: Blessuretijd       7.8       174
# 9424  Dreamworks Happy Holidays From Madagascar       6.8        71
#
#      AwardsReceived NetflixReleaseDate  \
# 0                74         2021-03-04
# 1                 1         2021-03-04
# 2              None         2021-03-03
# 3                 2         2021-03-03
# 4                 2         2021-03-03
# ...             ...                ...
# 9420           None         2015-04-14
# 9421              1         2015-04-14
# 9422           None         2015-04-14
# 9423           None         2015-04-14
# 9424           None         2015-04-14
#
#                                    ProductionHouse
# 0                        Canal+, Sandrew Metronome
# 1           Film 4, Monumental Pictures, Lionsgate
# 2                                             None
# 3                                             None
# 4                                             None
# ...                                            ...
# 9420  Revolution Studios, Thirteen Productions Llc
# 9421                                          None
# 9422                                          None
# 9423                                          None
# 9424                                          None
#
# [9425 rows x 6 columns]
